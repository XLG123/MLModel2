# %%
import pandas as pd

# Read the dataset into a pandas dataframe.
orig = pd.read_csv('tmdb_dataset.csv')
print(orig)

# Remove duplicated index column.
orig.drop(columns=orig.columns[0], axis=1, inplace=True)

# Remove duplicated movies indicated by id.
df = orig.drop_duplicates(subset='id', keep='last')

# Remove rows with vote count as 0.
df = df[df['vote_count']!=0]

# Remove unnecessary columns from the dataset.
df = df[['original_language', 'genre_ids', 'release_date', 'vote_average']]

# A function to get the ascii sum of the language from each movie.
def getASCIISum(language):
	return ord(language[0]) + ord(language[1])
df['original_language'] = df['original_language'].apply(getASCIISum)

# A function to remove month and dates from the release date column.
def removeMonthDate(release_date):
	return int(release_date[0:4])
df['release_date'] = df['release_date'].apply(removeMonthDate)

# A function to get the sum of genres of genre_ids from each movie.
def getGenreIDSum(genre_ids):
	genres = genre_ids[1:-1].split(', ')
	sum = 0
	for genre in genres:
		if len(genre) > 0:
			sum = sum + int(genre)
	return sum
df['genre_ids'] = df['genre_ids'].apply(getGenreIDSum)

# Rename the columns.
df.columns = ['Language', 'Genre', 'Year', 'Vote_Average']
dataset = df
print(dataset)
# dataset.to_csv('KMeanDataset.csv', index=False) # Save dataframe as a csv file.

# Normalize the four columns with Min-Max Scaling method.
# df['Language'] = (df['Language'] - df['Language'].min())/(df['Language'].max() - df['Language'].min())
# df['Genre'] = (df['Genre'] - df['Genre'].min())/(df['Genre'].max() - df['Genre'].min())
# df['Year'] = (df['Year'] - df['Year'].min())/(df['Year'].max() - df['Year'].min())
# df['Vote_Average'] = (df['Vote_Average'] - df['Vote_Average'].min())/(df['Vote_Average'].max() - df['Vote_Average'].min())
# datasetMMS = df
# datasetMMS.to_csv('KMeanDatasetMMS.csv', index=False) # Save dataframe as a csv file.
# Out:
#         Unnamed: 0  adult                     backdrop_path genre_ids      id  \
# 0                0  False  /6vYffq6NoneNmNPp6IsobnnlrHS.jpg      [99]  315946
# 1                1  False                               NaN      [16]  751212
# 2                2  False                               NaN      [16]  766094
# 3                3  False                               NaN      [16]  922010
# 4                4  False                               NaN      [16]  922011
# ...            ...    ...                               ...       ...     ...
# 568320      568320  False                               NaN      [53]  887385
# 568321      568321  False                               NaN        []  918969
# 568322      568322  False                               NaN        []  930902
# 568323      568323  False                               NaN      [99]  931766
# 568324      568324  False  /wdZdzWjgOXV8wPMbzGBnLdCGjYB.jpg      [99]  889714
#
#        original_language                      original_title  \
# 0                     fr                    Passage de Venus
# 1                     xx                   Le Singe Musicien
# 2                     xx                   La Rosace Magique
# 3                     xx                       Les Papillons
# 4                     xx                          Le Trapèze
# ...                  ...                                 ...
# 568320                es         Franklin sangra por la boca
# 568321                bn                            মানবজমিন
# 568322                en                 My Transparent Life
# 568323                en  Carbon: The Unauthorised Biography
# 568324                de                          Auf Anfang
#
#                                                  overview  popularity  \
# 0       Photo sequence of the rare transit of Venus ov...       6.169
# 1       A pre-cinematograph colour animation of the mo...       1.193
# 2       Praxinoscope strip of a shifting rosette. Seri...       0.833
# 3       Praxinoscope animation of a butterfly flutteri...       0.600
# 4       Praxinoscope animation of a man spinning aroun...       0.600
# ...                                                   ...         ...
# 568320                                                NaN       1.078
# 568321  It is based on a relationship tale and various...       0.777
# 568322  My Transparent Life chronicles the journey of ...       1.028
# 568323  With Carbon in the news every day, you might t...       2.150
# 568324  Michael Scholly is released 28 years after bei...       1.245
#
#                              poster_path release_date  \
# 0        /XWPDZzK7N2WQcejI8W96IxZEeP.jpg   1874-12-09
# 1       /fx2gnyV2n9KdOCyGzQtVnpB9bIg.jpg   1878-05-07
# 2       /5zeVMAp3R4QHGarSc4Bf3B1uBY2.jpg   1878-05-07
# 3       /nH9Lsvdo3icACe3AaW6j6YrbdR2.jpg   1878-05-07
# 4        /ykhF8AiAhSeKTDl1FfnlR7le7I.jpg   1878-05-07
# ...                                  ...          ...
# 568320                               NaN   2022-03-31
# 568321                               NaN   2022-03-31
# 568322  /ccX5sMhbpJVCi7oQlR55PIuXKQl.jpg   2022-03-31
# 568323  /1oRDIZyjM16RzFIbijvOIsJW5Ra.jpg   2022-03-31
# 568324  /pFULrEXU7KoUVqt1XComiIqvFOe.jpg   2022-03-31
#
#                                      title  video  vote_average  vote_count
# 0                         Passage of Venus  False           6.2          63
# 1                      The Musician Monkey  False           6.6           9
# 2                        The Magic Rosette  False           6.4           7
# 3                            Les Papillons  False           0.0           0
# 4                               Le Trapèze  False           0.0           0
# ...                                    ...    ...           ...         ...
# 568320         Franklin sangra por la boca  False           0.0           0
# 568321                          Manabjamin  False           0.0           0
# 568322                 My Transparent Life  False           0.0           0
# 568323  Carbon: The Unauthorised Biography  False           0.0           0
# 568324                          Auf Anfang  False           0.0           0
#
# [568325 rows x 15 columns]
#         Language  Genre  Year  Vote_Average
# 0            216     99  1874           6.2
# 1            240     16  1878           6.6
# 2            240     16  1878           6.4
# 21           240    115  1878           6.7
# 22           240     99  1881           5.4
# ...          ...    ...   ...           ...
# 567722       228  10886  2022          10.0
# 567725       211  10402  2022          10.0
# 567737       216    135  2022           6.0
# 567741       211     99  2022           9.0
# 567743       211  10501  2022          10.0
#
# [210810 rows x 4 columns]
